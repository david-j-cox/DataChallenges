# %% [markdown]
# # The Clairvoyant Constructor
#
# # Goals
# You are a data scientist at a large construction company. To submit more competitive bids for contracts, the head of analytics and data science would like you to forecast core construction material costs. You have access to the pricing information (per unit, in dollars) for the company’s past purchases of plywood, sheetrock, steel beams, rebar, and glass contracts over the past ten years in csv format.
#
# Currently, the company can purchase futures contracts in a material for up to six months. Thus, your manager is most interested in forecasting the price of each commodity up to six months into the future. In particular, your manager feels it would be really useful to understand when a commodity price is about to increase temporarily, so the company can buy the commodity early or wait until after the temporary increase.
#
# ### Answers:
# 1. Steel prices seem to be at the lowest around May/June and again in August.
# 1. Rebar prices seem to be lowest around April.
# 1. Glass prices seem to be lowest around October (though there is a fair amount of missing data over the winter months).
# 1. Concrete prices seem to remain relatively low throughout the year. But, prices spike between May and August. So the company should buy before that time hits and buy enough to last through that period.
# 1. Plywood prices follow a similar trend as concrete. Recommendation is buy enough to last through the May-to-August period.
#
# #### NB: There is a lot of missing data. If the company is interested in optimizing purchasing during low periods and developing more accurate forecasting models, then I would recommend collecting more market data on prices outside of just when they make purchases.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import sys
from pandas_profiling import ProfileReport

# %%
# Read in the data for EDA. 
data = pd.read_csv('construction_material_prices_2008_2018.csv', low_memory=False)
df = data.copy()
df_cols = list(df)

# %%
profile = ProfileReport(df)
profile
# Out:
# ...
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.5.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Change the date col from category to datetime type
df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'], infer_datetime_format=True)

# %%
df.dtypes
# Out:
# Unnamed: 0        datetime64[ns]
# price_steel              float64
# price_rebar              float64
# price_glass              float64
# price_concrete           float64
# price_plywood            float64
# dtype: object

# %%
# Take a look at what the time-series look like visually
df_plot = df.set_index('Unnamed: 0')
df_plot.plot(subplots=True, figsize=(15, 10))
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
# Same visualization as above using interpolated vals
df_plot_cols = list(df_plot)
df_interpol = df_plot.resample('W').mean()
for i in df_plot_cols:
    df_interpol[i] = df_interpol[i].interpolate(method='time')
df_interpol = df_interpol.dropna()
df_interpol.plot(subplots=True, figsize=(15, 10))
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
# Check out autocorrelation over 44 weeks (6.5 months)
from statsmodels.tsa.stattools import acf
for i in df_plot_cols:
    lac_acf = acf(df_interpol[i], nlags=44, fft=False)
    plt.figure(figsize=(15,5))
    plt.subplot(121)
    plt.stem(lac_acf)
    plt.axhline(y=0, linestyle='-', color='black')
    plt.xlabel('Lag', fontsize=20)
    plt.ylabel('ACF', fontsize=20)
    plt.title(i, fontsize=20)
    plt.show()
# Out:
# /Users/dcox/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   import sys

# %% [markdown]
# ### It looks like there's some correlation between prices of each commodity around 180 days out. But, the correlations are relatively weak so probably not helpful to use this alone.

# %% [markdown]
# ### Decompose time series

# %%
import statsmodels.api as sm
from pylab import rcParams

for i in df_plot_cols:
    data = df_interpol[i]
    data_decomp = sm.tsa.seasonal_decompose(data, model='additive')
    fig = data_decomp.plot()
    plt.xlabel(i, fontsize=20)
    plt.show

# %% [markdown]
# ### All five commodities show fairly clear seasonality. Let's replot the same data but zooming in on a two-year span to see how the six-month time frames change.

# %%
from pylab import rcParams
rcParams['figure.figsize']=(10,5)
for i in df_plot_cols:
    data = df_interpol[i][-120:]
    data_decomp = sm.tsa.seasonal_decompose(data, model='additive')
    fig = data_decomp.plot()
    plt.xlabel(i, fontsize=20)
    plt.show

# %% [markdown]
# ### Unclear we need to run formal models to make recommendations on purchasing 6-months futures. The general trends above suggest:
# 1. Steel prices seem to be at the lowest around May/June and again in August.
# 1. Rebar prices seem to be lowest around April.
# 1. Glass prices seem to be lowest around October (though there is a fair amount of missing data over the winter months).
# 1. Concrete prices seem to remain relatively low throughout the year. But, prices spike between May and August. So the company should buy before that time hits and buy enough to last through that period.
# 1. Plywood prices follow a similar trend as concrete. Recommendation is buy enough to last through the May-to-August period.

# %% [markdown]
# ## Nevertheless, we can build a model to allow the manager to make predictions at any point in time. Because we have seasonality in our data and want to include a time trend, we can use SARIMAX or VARMAX.

# %%
# Some packages. 
from sklearn.model_selection import TimeSeriesSplit
import itertools
from statsmodels.tsa.statespace.sarimax import SARIMAX as smax
from statsmodels.tsa.statespace.varmax import VARMAX as vmax

# %%
# Find optimal params for steel
# Split data into training and test
X = df_interpol['price_steel']
train_size = int(len(X)*0.80)
X_train, X_test = X[0:train_size], X[train_size:len(X)]

# Grid search for optimal params
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
aic = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = smax(X_train, order=param, seasonal_order=param_seasonal, 
                       enforce_stationarity=True, enforce_invertibility=False)
            results = model.fit()
            aic.append(results.aic)
        except:
            continue
print('Lowest Steel AIC={}; SARIMAX{}x{}52'.format(min(aic), param, param_seasonal))

# %%
# Find optimal params for rebar
# Split data into training and test
X = df_interpol['price_rebar']
train_size = int(len(X)*0.80)
X_train, X_test = X[0:train_size], X[train_size:len(X)]

# Grid search for optimal params
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
aic = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = smax(X_train, order=param, seasonal_order=param_seasonal, 
                       enforce_stationarity=True, enforce_invertibility=False)
            results = model.fit()
            aic.append(results.aic)
        except:
            continue
print('Lowest Rebar AIC={}; SARIMAX{}x{}52'.format(min(aic), param, param_seasonal))

# %%
# Find optimal params for rebar
# Split data into training and test
X = df_interpol['price_glass']
train_size = int(len(X)*0.80)
X_train, X_test = X[0:train_size], X[train_size:len(X)]

# Grid search for optimal params
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
aic = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = smax(X_train, order=param, seasonal_order=param_seasonal, 
                       enforce_stationarity=True, enforce_invertibility=False)
            results = model.fit()
            aic.append(results.aic)
        except:
            continue
print('Lowest Rebar AIC={}; SARIMAX{}x{}52'.format(min(aic), param, param_seasonal))

# %%
# Find optimal params for rebar
# Split data into training and test
X = df_interpol['price_concrete']
train_size = int(len(X)*0.80)
X_train, X_test = X[0:train_size], X[train_size:len(X)]

# Grid search for optimal params
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
aic = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = smax(X_train, order=param, seasonal_order=param_seasonal, 
                       enforce_stationarity=True, enforce_invertibility=False)
            results = model.fit()
            aic.append(results.aic)
        except:
            continue
print('Lowest Concrete AIC={}; SARIMAX{}x{}52'.format(min(aic), param, param_seasonal))

# %%
# Find optimal params for rebar
# Split data into training and test
X = df_interpol['price_glass']
train_size = int(len(X)*0.80)
X_train, X_test = X[0:train_size], X[train_size:len(X)]

# Grid search for optimal params
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
aic = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = smax(X_train, order=param, seasonal_order=param_seasonal, 
                       enforce_stationarity=True, enforce_invertibility=False)
            results = model.fit()
            aic.append(results.aic)
        except:
            continue
print('Lowest Plywood AIC={}; SARIMAX{}x{}52'.format(min(aic), param, param_seasonal))

# %% [markdown]
# ### Same process for VARMAX

# %%
# Find optimal params for steel
# Split data into training and test
X = df_interpol['price_steel']
train_size = int(len(X)*0.80)
X_train, X_test = X[0:train_size], X[train_size:len(X)]

# Grid search for optimal params
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
aic = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = vmax(X_train, order=param, seasonal_order=param_seasonal, 
                       enforce_stationarity=True, enforce_invertibility=False)
            results = model.fit()
            aic.append(results.aic)
        except:
            continue
print('Lowest Steel AIC={}; VARMAX{}x{}52'.format(min(aic), param, param_seasonal))
